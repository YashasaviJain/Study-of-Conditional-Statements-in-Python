# %% [markdown]
# *   Name - Yashasavi Jain
#
# *   PRN - 25070123127
#
# *   Aim - Study of Conditional Statements in Python
#
# *   Batch - B-3

# %%
#1a. Check wheather a number is poositive, negaative, or zero
num = int(input("Enter a Number:"))
if num < 0:
  print("Number is Negative")
elif num > 0:
  print("Number is Positive")
else:
  print("Zero")
# Out:
# Enter a Number:9687
# Number is Positive

# %%
#2. Check wheather the given number is even or odd
num = int(input("Enter a Number:"))
if num % 2 == 0:
  print("Number is Even")
else:
  print("Number is Odd")
# Out:
# Enter a Number:70
# Number is Even

# %%
#3. Find the largest of three number
a = int(input("Enter the value of a:"))
b = int(input("Enter the value of b:"))
c = int(input("Enter the value of c:"))
if a>=b and a>=c:
  print("Largest:",a)
elif b>=a and b>=c:
  print("Largest:",b)
else:
  print("Largest:",c)
# Out:
# Enter the value of a:7
# Enter the value of b:7
# Enter the value of c:7
# Largest: 7

# %%
#4. Get input from user for a subject and
# Calculate grade using if-elif-else
marks = int(input("Enter Marks:"))
if marks >= 90:
  print("Grade A")
elif marks >= 75:
  print("Grade B")
elif marks >= 60:
  print("Grade C")
elif marks >= 40:
  print("Grade D")
else:
  print("Fail")
# Out:
# Enter Marks:76
# Grade B

# %%
#5. Check wheather a year is a leap year
year = int(input("Enter Year:"))
if (year%400==0) or (year%4==0 and year%100!=0):
  print("Leap Year")
else:
  print("Not a Leap Year")
# Out:
# Enter Year:2024
# Leap Year

# %%
#6. Write a Python program to increment the date by 1year
date = input("Enter the date in format {dd/mm/yyyy}:")
dd,mm,yy=date.split('/')
dd=int(dd)
mm=int(mm)
yy=int(yy)
if(mm==1 or mm==3 or mm==5 or mm==7 or mm==8 or mm==10 or mm==12):
  max1=31
elif(mm==4 or mm==6 or mm==9 or mm==11):
  max1=30
elif(yy%4==0 and yy%100!=0 or yy%400==0):
  max1=29
else:
  max1=28
if(mm<1 or mm>12):
  print("Date is Invalid.")
elif(dd<1 or dd>max1):
  print("Date is Invalid.")
elif(dd==max1 and mm!=12):
  dd=1
  mm=1
  yy=yy+1
  print("The incremented date is:",dd,mm,yy)
else:
  dd=dd+1
  print("the incremented date is:",dd,mm,yy)
# Out:
# Enter the date in format {dd/mm/yyyy}:01/01/2000
# the incremented date is: 2 1 2000

# %%
#7. Write a Pyrhon program to check Vowels and Consonant
ch = input("Enter a Character:")
if ch in 'aeiouAEIOU':
  print("Vowel")
else:
  print("Consonant")
# Out:
# Enter a Character:e
# Vowel

# %%
'''#8. Write a Python program to calculate the gross salary of an emplyee

 If basic <= 10000: HRA = 20%, DA = 80%

 If basic <= 20000: HRA = 25%, DA = 90%

 otherwise: HRA = 30%, DA = 95%'''

basic = float(input("Enter basic Salary:"))
if basic <= 10000:
  hra = basic * 0.20
  da + nasic * 0.80
elif basic <=20000:
  hra = nasic * 0.25
  da = basic * 0.90
else:
  hra = basic * 0.30
  da = basic * 0.95
gross = basic + hra + da
print("Gross Salary:", gross)
# Out:
# Enter basic Salary:80000
# Gross Salary: 180000.0

# %%
'''#9. Write a Python Program to Calculate income tax based on anual income:
Up to 2,50,000: No Tax
2,50,001 - 5,00,000: 5%
5,00,001 - 10,00,000: 20%
Above 10,00,000: 30%'''
income = float(input("Enter anual income:"))
if income <= 250000:
  tax = 0
elif income <= 500000:
  tax = (income - 250000) * 0.05
elif income <= 1000000:
  tax = (250000 * 0.05) + (income - 500000) * 0.20
else:
  tax = (250000 * 0.05) + (500000 * 0.20) + (income - 1000000) * 0.30
print("Income Tax:",tax)
# Out:
# Enter anual income:700000
# Income Tax: 52500.0

# %%
x = "Python,is,Easy"
a,b,c = x.split(',')
print(a)
print(b)
print(c)
# Out:
# Python
# is
# Easy
